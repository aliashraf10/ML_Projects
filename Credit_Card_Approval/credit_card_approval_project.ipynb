# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import accuracy_score 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
data = pd.read_csv('Credit_card.csv')
label = pd.read_csv("Credit_card_label.csv")
label
#Label = 0, credit card application accepted
#label = 1, credit card application rejected
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
data = data.merge(label, on = 'Ind_ID', how = 'left')
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
data.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
data.isna().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
data.drop(columns = 'Type_Occupation', inplace = True)

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
data.dropna(inplace = True)
#Using dropna after removing cloumn "Type_Occupation" to preserve most rows

data.isna().sum()
# Out:
# Ind_ID            0
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label             0
# dtype: int64

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 4     5009752      F         Y             N         0       315000.0
# 6     5009754      F         Y             N         0       315000.0
# 7     5009894      F         N             N         0       180000.0
# ...       ...    ...       ...           ...       ...            ...
# 1542  5118268      M         Y             N         1       360000.0
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
avg_income = data['Annual_income'].mean()
avg_income
# Out:
# 190775.04846256683

# %%
gender_income = data.groupby('GENDER')["Annual_income"].mean()

gender_income
# Out:
# GENDER
# F    172391.840021
# M    222485.245902
# Name: Annual_income, dtype: float64

# %%
label_counts = data["label"].value_counts()
plt.pie(label_counts, labels = ["Credit Card Approved","Credit Card Rejected"], autopct = '%1.1f%%')
plt.title("Credit Approval Status")
plt.show()

# %%
data.groupby("Type_Income")["Annual_income"].mean()
# Out:
# Type_Income
# Commercial associate    233880.169972
# Pensioner               154964.866795
# State servant           210130.434783
# Working                 180154.579974
# Name: Annual_income, dtype: float64

# %%
data.groupby("Propert_Owner")["Annual_income"].mean()
# Out:
# Propert_Owner
# N    183343.352601
# Y    194722.899181
# Name: Annual_income, dtype: float64

# %%
data.groupby("CHILDREN")["Annual_income"].mean()
# Out:
# CHILDREN
# 0     182400.735014
# 1     215498.657718
# 2     203309.302326
# 3     177862.500000
# 4     180000.000000
# 14    225000.000000
# Name: Annual_income, dtype: float64

# %%
sns.boxplot(x = 'Marital_status', y ='Annual_income', data =data)
plt.title("Annual Income variation by Marital Status")
plt.show()

# %%
sns.boxplot(x = 'EDUCATION', y ='Annual_income', data =data)
plt.title("Annual Income variation by Education")
plt.show()

# %%
data_imp = data[['Car_Owner','Propert_Owner','Annual_income','EDUCATION','label']]
data_imp
# Out:
#      Car_Owner Propert_Owner  Annual_income                      EDUCATION  \
# 0            Y             Y       180000.0               Higher education
# 1            Y             N       315000.0               Higher education
# 4            Y             N       315000.0               Higher education
# 6            Y             N       315000.0               Higher education
# 7            N             N       180000.0  Secondary / secondary special
# ...        ...           ...            ...                            ...
# 1542         Y             N       360000.0  Secondary / secondary special
# 1544         N             N       225000.0              Incomplete higher
# 1545         Y             Y       180000.0               Higher education
# 1546         Y             N       270000.0  Secondary / secondary special
# 1547         Y             Y       225000.0               Higher education
#
#       label
# 0         1
# 1         1
# 4         1
# 6         1
# ...

# %%
labelencoder = preprocessing.LabelEncoder()
data_imp['Car_Owner'] = labelencoder.fit_transform(data_imp['Car_Owner'])
data_imp['Propert_Owner'] = labelencoder.fit_transform(data_imp['Propert_Owner'])
data_imp['EDUCATION'] = labelencoder.fit_transform(data_imp['EDUCATION'])
# Out:
# C:\Users\alias\AppData\Local\Temp\ipykernel_38852\921566554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_imp['Car_Owner'] = labelencoder.fit_transform(data_imp['Car_Owner'])
# C:\Users\alias\AppData\Local\Temp\ipykernel_38852\921566554.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_imp['Propert_Owner'] = labelencoder.fit_transform(data_imp['Propert_Owner'])
# C:\Users\alias\AppData\Local\Temp\ipykernel_38852\921566554.py:4: SettingWithCopyWarning:
# ...

# %%
data_imp
# Out:
#       Car_Owner  Propert_Owner  Annual_income  EDUCATION  label
# 0             1              1       180000.0          1      1
# 1             1              0       315000.0          1      1
# 4             1              0       315000.0          1      1
# 6             1              0       315000.0          1      1
# 7             0              0       180000.0          4      1
# ...         ...            ...            ...        ...    ...
# 1542          1              0       360000.0          4      0
# 1544          0              0       225000.0          2      0
# 1545          1              1       180000.0          1      0
# 1546          1              0       270000.0          4      0
# 1547          1              1       225000.0          1      0
#
# [1496 rows x 5 columns]

# %%
X = data_imp.iloc[:, :-1]
y = data_imp.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 21)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
def modelperformance(predictions):
    print("Accuracy score of model is {}".format(accuracy_score(y_test,predictions)))

# %%
logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train)
y_pred = logreg.predict(X_test_scaled)
modelperformance(y_pred)
# Out:
# Accuracy score of model is 0.8933333333333333

# %%
param_grid = {'n_neighbors' : [3,5,7,9,11],
              'weights' : ['uniform','distance'],
              'algorithm' : ['auto','kd_tree']}
gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=2)

# %%
gridkn.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'kd_tree'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
kn_pred = gridkn.predict(X_test_scaled)

# %%
modelperformance(kn_pred)
# Out:
# Accuracy score of model is 0.8933333333333333

# %%
svm = SVC()
param_grid_svr = {"C" : [0.01,0.1,0.5,1],
                  'kernel' : ['linear','rbf','poly']}
gridsvr = GridSearchCV(svm, param_grid_svr)

# %%
gridsvr.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
svc_pred = gridsvr.predict(X_test_scaled)
modelperformance(svc_pred)
# Out:
# Accuracy score of model is 0.8933333333333333
